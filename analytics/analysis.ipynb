# %%
# !pip install ydata-profiling pandas

# %%
import os
import logging
import warnings

# отключаем ворнинги
warnings.filterwarnings("ignore")

# отключаем прогресс-бары
os.environ["YDATA_PROFILING_DISABLE_PROGRESS_BAR"] = "1"
os.environ["PROGRESS_BAR_OFF"] = "True"

# отключаем логи библиотек
logging.getLogger("ydata_profiling").setLevel(logging.CRITICAL)
logging.getLogger("pandas_profiling").setLevel(logging.CRITICAL)
logging.getLogger("matplotlib").setLevel(logging.CRITICAL)

# %matplotlib inline

# %%
import sqlite3
from pathlib import Path

import pandas as pd

try:
    from ydata_profiling import ProfileReport
    HAS_PROFILING = True
except ImportError:
    HAS_PROFILING = False
    print("⚠ ydata_profiling не установлен — профили не будут строиться.")


from pathlib import Path

ROOT = Path.cwd()   # текущая директория ноутбука
DB_PATH = ROOT.parent / "db" / "shop.db"
print("Используем БД:", DB_PATH.resolve())

conn = sqlite3.connect(DB_PATH)
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Используем БД: C:\code\Projects\RecSys_case_final_arc\db\shop.db

# %%
def list_tables(connection):
    query = """
    SELECT name
    FROM sqlite_master
    WHERE type='table'
      AND name NOT LIKE 'sqlite_%'
    ORDER BY name
    """
    return pd.read_sql(query, connection)["name"].tolist()

tables = list_tables(conn)
tables
# Out:
# ['category',
#  'event',
#  'order_item',
#  'orders',
#  'product',
#  'recipe',
#  'recipe_product',
#  'session_info',
#  'user']

# %%
def load_table(connection, table_name: str) -> pd.DataFrame:
    return pd.read_sql(f"SELECT * FROM {table_name}", connection)

# Пример: посмотрим на product
if "product" in tables:
    df_product = load_table(conn, "product")
    display(df_product.head())
# Out:
#    id                                               name  \
# 0   1                             Абрикос мытый, Фрешбар
# 1   2  Абрикос Планета Витаминов без косточки заморож...
# 2   3                                   Абрикосы сушеные
# 3   5                                             Аджика
# 4   6                    Аджика / Соус Фирменный KERAKUR
#
#                                            image_url  price unit  \
# 0  https://img.vkusvill.ru/pim/images/site/62d3b0...  165.0   шт
# 1  https://img.vkusvill.ru/pim/images/site/a2549a...  199.0   шт
# 2  https://img.vkusvill.ru/pim/images/site/96ffdd...  328.0   шт
# 3  https://img.vkusvill.ru/pim/images/site/site/2...  184.0   шт
# 4  https://img.vkusvill.ru/pim/images/site/259f77...  335.0   шт
#
#    weight_value weight_unit  rating shelf_life_days  category_id  \
# 0         300.0           г     0.0            None            0
# 1         250.0           г     4.6            None            1
# 2         200.0           г     4.8            None            2
# 3         200.0           г     4.8            None            3
# 4         480.0           г     4.8            None            1
#
#                brand                                        description  \
# 0           ВкусВилл  Медовой спелости абрикосы, тщательно отобранны...
# 1  Планета Витаминов  Линейка Гурманики дополняется новым продуктом ...
# 2           ВкусВилл  Сушеные абрикосы способны быстро утолить голод...
# 3           ВкусВилл  Острая аджика с насыщенным вкусом и густой тек...
# 4            Kerakur  Аджика неострая , подается к мясным и куриным ...
#
#                                          composition  \
# 0                                     абрикос свежий
# 1                                            Абрикос
# 2                      абрикосы сушеные без косточки
# 3  перец красный сладкий свежий, паста томатная (...
# 4  красный перец, томатная паста, красный острый ...
#
#                                             metadata
# 0  {"category": "Фрукты", "subcategory": "Фруктов...
# 1  {"category": "Замороженные ягоды", "subcategor...
# 2  {"category": "Орехи, чипсы и снеки", "subcateg...
# 3  {"category": "Консервация", "subcategory": "Ху...
# 4  {"category": "Овощные консервы", "subcategory"...

# %%
reports_dir = Path("table_reports")
reports_dir.mkdir(exist_ok=True)

key_tables = ["user", "product", "orders", "order_item", "event"]

for t in key_tables:
    if t not in tables:
        continue
    print("=" * 60)
    print(f"⭐ Ключевая таблица: {t}")
    print("=" * 60)
    
    df = load_table(conn, t)
    display(df)
    
    if HAS_PROFILING and len(df) > 0:
        profile = ProfileReport(df, title=f"Key table profile: {t}", minimal=True)
        html_path = reports_dir / f"key_{t}_profile.html"
        profile.to_file(html_path)
        print(f"Profile для {t} сохранён в {html_path}\n")
# Out:
# ============================================================
# ⭐ Ключевая таблица: user
# ============================================================
#    id username                                      password_hash  \
# 0   1     asnp  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 1   2     test  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 2   3  new_akk  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 3   4    test2  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 4   5    test3  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 5   6  test_10  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
#
#             created_at
# 0  2025-11-15 09:36:46
# 1  2025-11-15 09:49:22
# 2  2025-11-15 11:00:48
# 3  2025-11-15 13:49:29
# 4  2025-11-15 13:50:27
# 5  2025-11-16 21:45:32
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 4/4 [00:00<00:00, 879.26it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profile для user сохранён в table_reports\key_user_profile.html
#
# ============================================================
# ⭐ Ключевая таблица: product
# ============================================================
#          id                                               name  \
# 0         1                             Абрикос мытый, Фрешбар
# 1         2  Абрикос Планета Витаминов без косточки заморож...
# 2         3                                   Абрикосы сушеные
# 3         5                                             Аджика
# 4         6                    Аджика / Соус Фирменный KERAKUR
# ...     ...                                                ...
# 8704  10458        Зразы "Сахалинские" из горбуши с сыром, зам
# 8705  10459                    Зубатка пестрая стейк мороженая
# 8706  10460                          Зубатка пестрая стейк зам
# 8707  10461                          Зубатка пестрая стейк зам
# 8708  10462                                  Звездочки медовые
#
#                                               image_url  price unit  \
# 0     https://img.vkusvill.ru/pim/images/site/62d3b0...  165.0   шт
# 1     https://img.vkusvill.ru/pim/images/site/a2549a...  199.0   шт
# 2     https://img.vkusvill.ru/pim/images/site/96ffdd...  328.0   шт
# 3     https://img.vkusvill.ru/pim/images/site/site/2...  184.0   шт
# 4     https://img.vkusvill.ru/pim/images/site/259f77...  335.0   шт
# ...                                                 ...    ...  ...
# 8704  https://img.vkusvill.ru/pim/images/site/5478ed...  425.0   шт
# 8705  https://img.vkusvill.ru/pim/images/site/1a96f9...  920.0   кг
# 8706  https://img.vkusvill.ru/pim/images/site/7ebdd6...  910.0   кг
# 8707  https://img.vkusvill.ru/pim/images/site/9b5aa6...  595.0   шт
# 8708  https://img.vkusvill.ru/pim/images/site/775306...   98.0   шт
#
#       weight_value weight_unit  rating shelf_life_days  category_id  \
# 0            300.0           г     0.0            None            0
# 1            250.0           г     4.6            None            1
# 2            200.0           г     4.8            None            2
# 3            200.0           г     4.8            None            3
# 4            480.0           г     4.8            None            1
# ...            ...         ...     ...             ...          ...
# 8704         300.0           г     4.7            None           10
# 8705           NaN                 4.6            None           10
# 8706           NaN                 4.9            None           10
# 8707         600.0           г     4.7            None           10
# 8708         200.0           г     4.9            None           19
#
#                   brand                                        description  \
# 0              ВкусВилл  Медовой спелости абрикосы, тщательно отобранны...
# 1     Планета Витаминов  Линейка Гурманики дополняется новым продуктом ...
# 2              ВкусВилл  Сушеные абрикосы способны быстро утолить голод...
# 3              ВкусВилл  Острая аджика с насыщенным вкусом и густой тек...
# 4               Kerakur  Аджика неострая , подается к мясным и куриным ...
# ...                 ...                                                ...
# 8704           ВкусВилл  Зразы с горбушей и сыром, которые при обжарке ...
# 8705           ВкусВилл  Дикую зубатку вылавливают в Баренцевом море. А...
# 8706           ВкусВилл  Замороженные стейки дикой пёстрой зубатки. Мяс...
# 8707           ВкусВилл  Замороженные стейки дикой пёстрой зубатки. Мяс...
# 8708           ВкусВилл  Аппетитные мультизлаковые звёздочки с натураль...
#
#                                             composition  \
# 0                                        абрикос свежий
# 1                                               Абрикос
# 2                         абрикосы сушеные без косточки
# 3     перец красный сладкий свежий, паста томатная (...
# 4     красный перец, томатная паста, красный острый ...
# ...                                                 ...
# 8704  горбуша,  сыр полутвердый м.д.ж в сухом вещест...
# 8705  Зубатка пестрая, вода питьевая (защитная глазу...
# 8706  зубатка пёстрая, вода питьевая (защитная глазурь)
# 8707  Зубатка пестрая, вода питьевая (защитная глазу...
# 8708  зерновые продукты (крупа кукурузная,  крупа ри...
#
#                                                metadata
# 0     {"category": "Фрукты", "subcategory": "Фруктов...
# 1     {"category": "Замороженные ягоды", "subcategor...
# 2     {"category": "Орехи, чипсы и снеки", "subcateg...
# 3     {"category": "Консервация", "subcategory": "Ху...
# 4     {"category": "Овощные консервы", "subcategory"...
# ...                                                 ...
# 8704  {"category": "Рыба, икра и морепродукты", "sub...
# 8705  {"category": "Рыба, икра и морепродукты", "sub...
# 8706  {"category": "Рыба, икра и морепродукты", "sub...
# 8707  {"category": "Рыба, икра и морепродукты", "sub...
# 8708  {"category": "Крупы, макароны, мука", "subcate...
#
# [8709 rows x 14 columns]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 14/14 [00:02<00:00,  5.04it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profile для product сохранён в table_reports\key_product_profile.html
#
# ============================================================
# ⭐ Ключевая таблица: orders
# ============================================================
#     id  user_id           order_time   status  total_price
# 0    1        1  2025-11-15 09:48:31  created        354.0
# 1    2        2  2025-11-15 10:59:06  created        520.0
# 2    3        4  2025-11-15 13:50:20  created       8464.0
# 3    4        1  2025-11-16 15:49:44  created        199.0
# 4    5        1  2025-11-16 15:49:54  created       1974.0
# 5    6        1  2025-11-16 19:18:24  created        762.0
# 6    7        1  2025-11-16 19:38:38  created        821.0
# 7    8        1  2025-11-16 19:39:16  created        768.0
# 8    9        1  2025-11-16 19:52:16  created       2076.0
# 9   10        1  2025-11-16 19:53:40  created        342.0
# 10  11        1  2025-11-16 20:07:52  created       1143.0
# 11  12        1  2025-11-16 21:15:45  created        885.0
# 12  13        1  2025-11-16 21:18:31  created        557.0
# 13  14        6  2025-11-16 21:48:38  created        115.0
# 14  15        6  2025-11-16 21:49:24  created        907.0
# 15  16        6  2025-11-16 21:50:41  created        844.0
# 16  17        6  2025-11-16 21:51:10  created        397.0
# 17  18        6  2025-11-16 21:51:43  created       1222.0
# 18  19        1  2025-11-16 22:41:34  created        890.0
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 562.90it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profile для orders сохранён в table_reports\key_orders_profile.html
#
# ============================================================
# ⭐ Ключевая таблица: order_item
# ============================================================
#     id  order_id  product_id  quantity  price
# 0    1         1           2         1  199.0
# 1    2         1        4188         1   48.0
# 2    3         1        1040         1  107.0
# 3    4         2        3088         1  288.0
# 4    5         2        9182         1  125.0
# 5    6         2        1040         1  107.0
# 6    7         3           5        46  184.0
# 7    8         4           2         1  199.0
# 8    9         5           7         5  335.0
# 9   10         5           5         1  184.0
# 10  11         5        4324         1  115.0
# 11  12         6           1         1  165.0
# 12  13         6           2         3  199.0
# 13  14         7           1         1  165.0
# 14  15         7           3         2  328.0
# 15  16         8        4815         2  129.0
# 16  17         8        4838         2  255.0
# 17  18         9           1         3  165.0
# 18  19         9           2         3  199.0
# 19  20         9           3         3  328.0
# 20  21        10          40         1  342.0
# 21  22        11           1         1  165.0
# 22  23        11           3         1  328.0
# 23  24        11          30         2  325.0
# 24  25        12        4324         1  115.0
# 25  26        12       10128         1  209.0
# 26  27        12         446         1  239.0
# 27  28        12        7867         1   63.0
# 28  29        12        4567         1  259.0
# 29  30        13           1         1  165.0
# 30  31        13           2         1  199.0
# 31  32        13           9         1   85.0
# 32  33        13         748         1  108.0
# 33  34        14        4324         1  115.0
# 34  35        15        5580         1  252.0
# 35  36        15        4188         1   48.0
# 36  37        15        4627         1   94.0
# 37  38        15        1040         1  107.0
# 38  39        15        2049         1  218.0
# 39  40        15        3664         1  188.0
# 40  41        16        8721         1  271.0
# 41  42        16        9208         1  288.0
# 42  43        16        6640         1   95.0
# 43  44        16        6634         1  190.0
# 44  45        17        1040         1  107.0
# 45  46        17        1715         1  290.0
# 46  47        18        6636         1  190.0
# 47  48        18        6644         1  310.0
# 48  49        18        6641         1  180.0
# 49  50        18        6640         1   95.0
# 50  51        18        6637         1  111.0
# 51  52        18        6634         1  190.0
# 52  53        18          50         1  146.0
# 53  54        19           1         1  165.0
# 54  55        19           3         1  328.0
# 55  56        19        1040         1  107.0
# 56  57        19        1715         1  290.0
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11535.49it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profile для order_item сохранён в table_reports\key_order_item_profile.html
#
# ============================================================
# ⭐ Ключевая таблица: event
# ============================================================
#         id  user_id                        session_id           event_time  \
# 0        1        1  9f13a385d1b9412a9887d4bd176def1d  2025-11-15 09:36:56
# 1        2        1  9f13a385d1b9412a9887d4bd176def1d  2025-11-15 09:37:00
# 2        3        1  01ae5ea39d664a2bbbc1979550c860b1  2025-11-15 09:38:03
# 3        4        1  01ae5ea39d664a2bbbc1979550c860b1  2025-11-15 09:38:03
# 4        5        1  67d3755043144f90abac45e5fe2124ea  2025-11-15 09:42:40
# ...    ...      ...                               ...                  ...
# 1366  1367        1  8f7c92691f4f42bb9eb4832a8c8b31cf  2025-11-16 22:42:18
# 1367  1368        1  8f7c92691f4f42bb9eb4832a8c8b31cf  2025-11-16 22:42:18
# 1368  1369        1  8f7c92691f4f42bb9eb4832a8c8b31cf  2025-11-16 22:42:18
# 1369  1370        1  8f7c92691f4f42bb9eb4832a8c8b31cf  2025-11-16 22:42:18
# 1370  1371        1  8f7c92691f4f42bb9eb4832a8c8b31cf  2025-11-16 22:42:18
#
#           event_type  item_id     page_type   source experiment_key variant  \
# 0        add_to_cart      2.0       catalog  catalog           None    None
# 1        add_to_cart      5.0       catalog  catalog           None    None
# 2     rec_impression      2.0  recs_sidebar     recs           None    None
# 3     rec_impression      5.0  recs_sidebar     recs           None    None
# 4     rec_impression      2.0  recs_sidebar     recs           None    None
# ...              ...      ...           ...      ...            ...     ...
# 1366  rec_impression   4577.0  recs_sidebar     recs           None    None
# 1367  rec_impression   4862.0  recs_sidebar     recs           None    None
# 1368  rec_impression   6265.0  recs_sidebar     recs           None    None
# 1369  rec_impression   6377.0  recs_sidebar     recs           None    None
# 1370  rec_impression   8168.0  recs_sidebar     recs           None    None
#
#       position value                        request_id  \
# 0          2.0  None                              None
# 1          4.0  None                              None
# 2          1.0  None  f0f8a991516e4629852826a19158c722
# 3          2.0  None  f0f8a991516e4629852826a19158c722
# 4          1.0  None  5115c2734a1049d0901443dc6c18d642
# ...        ...   ...                               ...
# 1366       4.0  None  3a83f8a823e8413eb08528d209075458
# 1367       5.0  None  3a83f8a823e8413eb08528d209075458
# 1368       6.0  None  3a83f8a823e8413eb08528d209075458
# 1369       7.0  None  3a83f8a823e8413eb08528d209075458
# 1370       8.0  None  3a83f8a823e8413eb08528d209075458
#
#                                          metadata
# 0               {"query": null, "cart": {"2": 1}}
# 1       {"query": null, "cart": {"2": 1, "5": 1}}
# 2                                    {"cart": {}}
# 3                                    {"cart": {}}
# 4                                    {"cart": {}}
# ...                                           ...
# 1366  {"cart": {"4324": 1, "446": 1, "10128": 1}}
# 1367  {"cart": {"4324": 1, "446": 1, "10128": 1}}
# 1368  {"cart": {"4324": 1, "446": 1, "10128": 1}}
# 1369  {"cart": {"4324": 1, "446": 1, "10128": 1}}
# 1370  {"cart": {"4324": 1, "446": 1, "10128": 1}}
#
# [1371 rows x 14 columns]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 14/14 [00:00<00:00, 260.92it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Profile для event сохранён в table_reports\key_event_profile.html

# %%
def max_matching(adj: dict[int, list[int]]) -> dict[int, int]:

    matchR = {}

    def dfs(u, seen):
        for v in adj[u]:
            if v in seen:
                continue
            seen.add(v)

            if v not in matchR or dfs(matchR[v], seen):
                matchR[v] = u
                return True
        return False

    for u in adj:
        dfs(u, set())

    matchL = {u: v for v, u in matchR.items()}
    return matchL

# %%
adj = {
    1:  [2, 5, 7],
    2:  [1, 3],
    3:  [4, 8, 9, 12],
    4:  [5],
    5:  [1, 6, 7, 8],
    6:  [3, 9],
    7:  [2, 4, 6],
    8:  [10, 11],
    9:  [5, 7, 12],
    10: [8]
}



matching = max_matching(adj)
print(len(matching))
print(matching)
# Out:
# 10
# {7: 2, 2: 1, 3: 4, 4: 5, 6: 3, 5: 6, 1: 7, 8: 10, 10: 8, 9: 12}
