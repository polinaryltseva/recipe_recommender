# %%
# !pip install ydata-profiling pandas

# %%
# %pip install matplotlib

# %%
import os
import logging
import warnings

# отключаем ворнинги
warnings.filterwarnings("ignore")

# отключаем прогресс-бары
os.environ["YDATA_PROFILING_DISABLE_PROGRESS_BAR"] = "1"
os.environ["PROGRESS_BAR_OFF"] = "True"

# отключаем логи библиотек
logging.getLogger("ydata_profiling").setLevel(logging.CRITICAL)
logging.getLogger("pandas_profiling").setLevel(logging.CRITICAL)
logging.getLogger("matplotlib").setLevel(logging.CRITICAL)

# %matplotlib inline

# %%
import sqlite3
from pathlib import Path

import pandas as pd

try:
    from ydata_profiling import ProfileReport
    HAS_PROFILING = True
except ImportError:
    HAS_PROFILING = False
    print("⚠ ydata_profiling не установлен — профили не будут строиться.")


from pathlib import Path

ROOT = Path.cwd()   # текущая директория ноутбука
DB_PATH = ROOT.parent / "db" / "shop.db"
print("Используем БД:", DB_PATH.resolve())

conn = sqlite3.connect(DB_PATH)
# Out:
# ⚠ ydata_profiling не установлен — профили не будут строиться.
# Используем БД: /home/recsys1_user01/recipe_recommender/llm_work/recipe_recommender/db/shop.db

# %%
def list_tables(connection):
    query = """
    SELECT name
    FROM sqlite_master
    WHERE type='table'
      AND name NOT LIKE 'sqlite_%'
    ORDER BY name
    """
    return pd.read_sql(query, connection)["name"].tolist()

tables = list_tables(conn)
tables
# Out:
# ['category',
#  'event',
#  'order_item',
#  'orders',
#  'product',
#  'recipe',
#  'recipe_product',
#  'session_info',
#  'user']

# %%
def load_table(connection, table_name: str) -> pd.DataFrame:
    return pd.read_sql(f"SELECT * FROM {table_name}", connection)

# Пример: посмотрим на product
if "product" in tables:
    df_product = load_table(conn, "product")
    display(df_product.head())
# Out:
#    id                                               name  \
# 0   1                             Абрикос мытый, Фрешбар
# 1   2  Абрикос Планета Витаминов без косточки заморож...
# 2   3                                   Абрикосы сушеные
# 3   5                                             Аджика
# 4   6                    Аджика / Соус Фирменный KERAKUR
#
#                                            image_url  price unit  \
# 0  https://img.vkusvill.ru/pim/images/site/62d3b0...  165.0   шт
# 1  https://img.vkusvill.ru/pim/images/site/a2549a...  199.0   шт
# 2  https://img.vkusvill.ru/pim/images/site/96ffdd...  328.0   шт
# 3  https://img.vkusvill.ru/pim/images/site/site/2...  184.0   шт
# 4  https://img.vkusvill.ru/pim/images/site/259f77...  335.0   шт
#
#    weight_value weight_unit  rating shelf_life_days  category_id  \
# 0         300.0           г     0.0            None            0
# 1         250.0           г     4.6            None            1
# 2         200.0           г     4.8            None            2
# 3         200.0           г     4.8            None            3
# 4         480.0           г     4.8            None            1
#
#                brand                                        description  \
# 0           ВкусВилл  Медовой спелости абрикосы, тщательно отобранны...
# 1  Планета Витаминов  Линейка Гурманики дополняется новым продуктом ...
# 2           ВкусВилл  Сушеные абрикосы способны быстро утолить голод...
# 3           ВкусВилл  Острая аджика с насыщенным вкусом и густой тек...
# 4            Kerakur  Аджика неострая , подается к мясным и куриным ...
#
#                                          composition  \
# 0                                     абрикос свежий
# 1                                            Абрикос
# 2                      абрикосы сушеные без косточки
# 3  перец красный сладкий свежий, паста томатная (...
# 4  красный перец, томатная паста, красный острый ...
#
#                                             metadata
# 0  {"category": "Фрукты", "subcategory": "Фруктов...
# 1  {"category": "Замороженные ягоды", "subcategor...
# 2  {"category": "Орехи, чипсы и снеки", "subcateg...
# 3  {"category": "Консервация", "subcategory": "Ху...
# 4  {"category": "Овощные консервы", "subcategory"...

# %%
reports_dir = Path("table_reports")
reports_dir.mkdir(exist_ok=True)

key_tables = ["user", "product", "orders", "order_item", "event"]

for t in key_tables:
    if t not in tables:
        continue
    print("=" * 60)
    print(f"⭐ Ключевая таблица: {t}")
    print("=" * 60)
    
    df = load_table(conn, t)
    display(df)
    
    if HAS_PROFILING and len(df) > 0:
        profile = ProfileReport(df, title=f"Key table profile: {t}", minimal=True)
        html_path = reports_dir / f"key_{t}_profile.html"
        profile.to_file(html_path)
        print(f"Profile для {t} сохранён в {html_path}\n")
# Out:
# ============================================================
# ⭐ Ключевая таблица: user
# ============================================================
#    id username                                      password_hash  \
# 0   1   151515  a6e639253cd20c3caf6f4f24049ba6ff2d414ba14ab738...
# 1   2     asnp  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
#
#    id_ab_group name_ab_group           created_at
# 0            1      llm_recs  2025-11-18 13:26:36
# 1            0  ease_popular  2025-11-18 13:26:51
# ============================================================
# ⭐ Ключевая таблица: product
# ============================================================
#          id                                               name  \
# 0         1                             Абрикос мытый, Фрешбар
# 1         2  Абрикос Планета Витаминов без косточки заморож...
# 2         3                                   Абрикосы сушеные
# 3         5                                             Аджика
# 4         6                    Аджика / Соус Фирменный KERAKUR
# ...     ...                                                ...
# 8704  10458        Зразы "Сахалинские" из горбуши с сыром, зам
# 8705  10459                    Зубатка пестрая стейк мороженая
# 8706  10460                          Зубатка пестрая стейк зам
# 8707  10461                          Зубатка пестрая стейк зам
# 8708  10462                                  Звездочки медовые
#
#                                               image_url  price unit  \
# 0     https://img.vkusvill.ru/pim/images/site/62d3b0...  165.0   шт
# 1     https://img.vkusvill.ru/pim/images/site/a2549a...  199.0   шт
# 2     https://img.vkusvill.ru/pim/images/site/96ffdd...  328.0   шт
# 3     https://img.vkusvill.ru/pim/images/site/site/2...  184.0   шт
# 4     https://img.vkusvill.ru/pim/images/site/259f77...  335.0   шт
# ...                                                 ...    ...  ...
# 8704  https://img.vkusvill.ru/pim/images/site/5478ed...  425.0   шт
# 8705  https://img.vkusvill.ru/pim/images/site/1a96f9...  920.0   кг
# 8706  https://img.vkusvill.ru/pim/images/site/7ebdd6...  910.0   кг
# 8707  https://img.vkusvill.ru/pim/images/site/9b5aa6...  595.0   шт
# 8708  https://img.vkusvill.ru/pim/images/site/775306...   98.0   шт
#
#       weight_value weight_unit  rating shelf_life_days  category_id  \
# 0            300.0           г     0.0            None            0
# 1            250.0           г     4.6            None            1
# 2            200.0           г     4.8            None            2
# 3            200.0           г     4.8            None            3
# 4            480.0           г     4.8            None            1
# ...            ...         ...     ...             ...          ...
# 8704         300.0           г     4.7            None           10
# 8705           NaN                 4.6            None           10
# 8706           NaN                 4.9            None           10
# 8707         600.0           г     4.7            None           10
# 8708         200.0           г     4.9            None           19
#
#                   brand                                        description  \
# 0              ВкусВилл  Медовой спелости абрикосы, тщательно отобранны...
# 1     Планета Витаминов  Линейка Гурманики дополняется новым продуктом ...
# 2              ВкусВилл  Сушеные абрикосы способны быстро утолить голод...
# 3              ВкусВилл  Острая аджика с насыщенным вкусом и густой тек...
# 4               Kerakur  Аджика неострая , подается к мясным и куриным ...
# ...                 ...                                                ...
# 8704           ВкусВилл  Зразы с горбушей и сыром, которые при обжарке ...
# 8705           ВкусВилл  Дикую зубатку вылавливают в Баренцевом море. А...
# 8706           ВкусВилл  Замороженные стейки дикой пёстрой зубатки. Мяс...
# 8707           ВкусВилл  Замороженные стейки дикой пёстрой зубатки. Мяс...
# 8708           ВкусВилл  Аппетитные мультизлаковые звёздочки с натураль...
#
#                                             composition  \
# 0                                        абрикос свежий
# 1                                               Абрикос
# 2                         абрикосы сушеные без косточки
# 3     перец красный сладкий свежий, паста томатная (...
# 4     красный перец, томатная паста, красный острый ...
# ...                                                 ...
# 8704  горбуша,  сыр полутвердый м.д.ж в сухом вещест...
# 8705  Зубатка пестрая, вода питьевая (защитная глазу...
# 8706  зубатка пёстрая, вода питьевая (защитная глазурь)
# 8707  Зубатка пестрая, вода питьевая (защитная глазу...
# 8708  зерновые продукты (крупа кукурузная,  крупа ри...
#
#                                                metadata
# 0     {"category": "Фрукты", "subcategory": "Фруктов...
# 1     {"category": "Замороженные ягоды", "subcategor...
# 2     {"category": "Орехи, чипсы и снеки", "subcateg...
# 3     {"category": "Консервация", "subcategory": "Ху...
# 4     {"category": "Овощные консервы", "subcategory"...
# ...                                                 ...
# 8704  {"category": "Рыба, икра и морепродукты", "sub...
# 8705  {"category": "Рыба, икра и морепродукты", "sub...
# 8706  {"category": "Рыба, икра и морепродукты", "sub...
# 8707  {"category": "Рыба, икра и морепродукты", "sub...
# 8708  {"category": "Крупы, макароны, мука", "subcate...
#
# [8709 rows x 14 columns]
# ============================================================
# ⭐ Ключевая таблица: orders
# ============================================================
# Empty DataFrame
# Columns: [id, user_id, order_time, status, total_price]
# Index: []
# ============================================================
# ⭐ Ключевая таблица: order_item
# ============================================================
# Empty DataFrame
# Columns: [id, order_id, product_id, quantity, price]
# Index: []
# ============================================================
# ⭐ Ключевая таблица: event
# ============================================================
#     id  user_id                        session_id           event_time  \
# 0    1        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 1    2        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 2    3        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 3    4        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 4    5        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 5    6        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 6    7        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 7    8        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 8    9        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:27:34
# 9   10        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
# 10  11        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
# 11  12        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
# 12  13        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
# 13  14        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
# 14  15        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
# 15  16        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
# 16  17        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
# 17  18        2  1fe87b27d12c4f82b361074edafa9e50  2025-11-18 13:28:16
#
#         event_type  item_id     page_type   source experiment_key  \
# 0      add_to_cart        1       catalog  catalog           None
# 1   rec_impression     4577  recs_sidebar     recs   main_recs_ab
# 2   rec_impression    10124  recs_sidebar     recs   main_recs_ab
# 3   rec_impression     7186  recs_sidebar     recs   main_recs_ab
# 4   rec_impression     6922  recs_sidebar     recs   main_recs_ab
# 5   rec_impression     4718  recs_sidebar     recs   main_recs_ab
# 6   rec_impression     9524  recs_sidebar     recs   main_recs_ab
# 7   rec_impression     6998  recs_sidebar     recs   main_recs_ab
# 8   rec_impression    10036  recs_sidebar     recs   main_recs_ab
# 9      add_to_cart        2       catalog  catalog           None
# 10  rec_impression     4577  recs_sidebar     recs   main_recs_ab
# 11  rec_impression    10124  recs_sidebar     recs   main_recs_ab
# 12  rec_impression     7186  recs_sidebar     recs   main_recs_ab
# 13  rec_impression     6922  recs_sidebar     recs   main_recs_ab
# 14  rec_impression     4718  recs_sidebar     recs   main_recs_ab
# 15  rec_impression     9524  recs_sidebar     recs   main_recs_ab
# 16  rec_impression     6998  recs_sidebar     recs   main_recs_ab
# 17  rec_impression    10036  recs_sidebar     recs   main_recs_ab
#
#          variant  position value                        request_id  \
# 0           None         1  None                              None
# 1   ease_popular         1  None  6ad0266e2bc9464894db3d168dc630e4
# 2   ease_popular         2  None  6ad0266e2bc9464894db3d168dc630e4
# 3   ease_popular         3  None  6ad0266e2bc9464894db3d168dc630e4
# 4   ease_popular         4  None  6ad0266e2bc9464894db3d168dc630e4
# 5   ease_popular         5  None  6ad0266e2bc9464894db3d168dc630e4
# 6   ease_popular         6  None  6ad0266e2bc9464894db3d168dc630e4
# 7   ease_popular         7  None  6ad0266e2bc9464894db3d168dc630e4
# 8   ease_popular         8  None  6ad0266e2bc9464894db3d168dc630e4
# 9           None         2  None                              None
# 10  ease_popular         1  None  6b061df08d5c4d53bb975b82e1fdd1b2
# 11  ease_popular         2  None  6b061df08d5c4d53bb975b82e1fdd1b2
# 12  ease_popular         3  None  6b061df08d5c4d53bb975b82e1fdd1b2
# 13  ease_popular         4  None  6b061df08d5c4d53bb975b82e1fdd1b2
# 14  ease_popular         5  None  6b061df08d5c4d53bb975b82e1fdd1b2
# 15  ease_popular         6  None  6b061df08d5c4d53bb975b82e1fdd1b2
# 16  ease_popular         7  None  6b061df08d5c4d53bb975b82e1fdd1b2
# 17  ease_popular         8  None  6b061df08d5c4d53bb975b82e1fdd1b2
#
#                              metadata
# 0   {"query": null, "cart": {"1": 1}}
# 1                  {"cart": {"1": 1}}
# 2                  {"cart": {"1": 1}}
# 3                  {"cart": {"1": 1}}
# 4                  {"cart": {"1": 1}}
# 5                  {"cart": {"1": 1}}
# 6                  {"cart": {"1": 1}}
# 7                  {"cart": {"1": 1}}
# 8                  {"cart": {"1": 1}}
# 9   {"query": null, "cart": {"2": 1}}
# 10                 {"cart": {"2": 1}}
# 11                 {"cart": {"2": 1}}
# 12                 {"cart": {"2": 1}}
# 13                 {"cart": {"2": 1}}
# 14                 {"cart": {"2": 1}}
# 15                 {"cart": {"2": 1}}
# 16                 {"cart": {"2": 1}}
# 17                 {"cart": {"2": 1}}

# %%
def max_matching(adj: dict[int, list[int]]) -> dict[int, int]:

    matchR = {}

    def dfs(u, seen):
        for v in adj[u]:
            if v in seen:
                continue
            seen.add(v)

            if v not in matchR or dfs(matchR[v], seen):
                matchR[v] = u
                return True
        return False

    for u in adj:
        dfs(u, set())

    matchL = {u: v for v, u in matchR.items()}
    return matchL

# %%
adj = {
    1:  [2, 5, 7],
    2:  [1, 3],
    3:  [4, 8, 9, 12],
    4:  [5],
    5:  [1, 6, 7, 8],
    6:  [3, 9],
    7:  [2, 4, 6],
    8:  [10, 11],
    9:  [5, 7, 12],
    10: [8]
}



matching = max_matching(adj)
print(len(matching))
print(matching)
# Out:
# 10
# {7: 2, 2: 1, 3: 4, 4: 5, 6: 3, 5: 6, 1: 7, 8: 10, 10: 8, 9: 12}
