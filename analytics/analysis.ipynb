# %%
# !pip install ydata-profiling pandas

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.60.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /home/recsys1_user01/recipe_recommender/.venv/lib/python3.12/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/recsys1_user01/recipe_recommender/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/recsys1_user01/recipe_recommender/.venv/lib/python3.12/site-packages (from matplotlib) (12.0.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/recsys1_user01/recipe_recommender/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/recsys1_user01/recipe_recommender/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 31.6 MB/s eta 0:00:0000:0100:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 28.5 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 65.6 MB/s eta 0:00:00:00:01
# Downloading kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 47.0 MB/s eta 0:00:00
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.60.1 kiwisolver-1.4.9 matplotlib-3.10.7 pyparsing-3.2.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import logging
import warnings

# отключаем ворнинги
warnings.filterwarnings("ignore")

# отключаем прогресс-бары
os.environ["YDATA_PROFILING_DISABLE_PROGRESS_BAR"] = "1"
os.environ["PROGRESS_BAR_OFF"] = "True"

# отключаем логи библиотек
logging.getLogger("ydata_profiling").setLevel(logging.CRITICAL)
logging.getLogger("pandas_profiling").setLevel(logging.CRITICAL)
logging.getLogger("matplotlib").setLevel(logging.CRITICAL)

# %matplotlib inline

# %%
import sqlite3
from pathlib import Path

import pandas as pd

try:
    from ydata_profiling import ProfileReport
    HAS_PROFILING = True
except ImportError:
    HAS_PROFILING = False
    print("⚠ ydata_profiling не установлен — профили не будут строиться.")


from pathlib import Path

ROOT = Path.cwd()   # текущая директория ноутбука
DB_PATH = ROOT.parent / "db" / "shop.db"
print("Используем БД:", DB_PATH.resolve())

conn = sqlite3.connect(DB_PATH)
# Out:
# ⚠ ydata_profiling не установлен — профили не будут строиться.
# Используем БД: /home/recsys1_user01/recipe_recommender/llm_work/recipe_recommender/db/shop.db

# %%
def list_tables(connection):
    query = """
    SELECT name
    FROM sqlite_master
    WHERE type='table'
      AND name NOT LIKE 'sqlite_%'
    ORDER BY name
    """
    return pd.read_sql(query, connection)["name"].tolist()

tables = list_tables(conn)
tables
# Out:
# ['category',
#  'event',
#  'order_item',
#  'orders',
#  'product',
#  'recipe',
#  'recipe_product',
#  'session_info',
#  'user']

# %%
def load_table(connection, table_name: str) -> pd.DataFrame:
    return pd.read_sql(f"SELECT * FROM {table_name}", connection)

# Пример: посмотрим на product
if "product" in tables:
    df_product = load_table(conn, "product")
    display(df_product.head())
# Out:
#    id                                               name  \
# 0   1                             Абрикос мытый, Фрешбар
# 1   2  Абрикос Планета Витаминов без косточки заморож...
# 2   3                                   Абрикосы сушеные
# 3   5                                             Аджика
# 4   6                    Аджика / Соус Фирменный KERAKUR
#
#                                            image_url  price unit  \
# 0  https://img.vkusvill.ru/pim/images/site/62d3b0...  165.0   шт
# 1  https://img.vkusvill.ru/pim/images/site/a2549a...  199.0   шт
# 2  https://img.vkusvill.ru/pim/images/site/96ffdd...  328.0   шт
# 3  https://img.vkusvill.ru/pim/images/site/site/2...  184.0   шт
# 4  https://img.vkusvill.ru/pim/images/site/259f77...  335.0   шт
#
#    weight_value weight_unit  rating shelf_life_days  category_id  \
# 0         300.0           г     0.0            None            0
# 1         250.0           г     4.6            None            1
# 2         200.0           г     4.8            None            2
# 3         200.0           г     4.8            None            3
# 4         480.0           г     4.8            None            1
#
#                brand                                        description  \
# 0           ВкусВилл  Медовой спелости абрикосы, тщательно отобранны...
# 1  Планета Витаминов  Линейка Гурманики дополняется новым продуктом ...
# 2           ВкусВилл  Сушеные абрикосы способны быстро утолить голод...
# 3           ВкусВилл  Острая аджика с насыщенным вкусом и густой тек...
# 4            Kerakur  Аджика неострая , подается к мясным и куриным ...
#
#                                          composition  \
# 0                                     абрикос свежий
# 1                                            Абрикос
# 2                      абрикосы сушеные без косточки
# 3  перец красный сладкий свежий, паста томатная (...
# 4  красный перец, томатная паста, красный острый ...
#
#                                             metadata
# 0  {"category": "Фрукты", "subcategory": "Фруктов...
# 1  {"category": "Замороженные ягоды", "subcategor...
# 2  {"category": "Орехи, чипсы и снеки", "subcateg...
# 3  {"category": "Консервация", "subcategory": "Ху...
# 4  {"category": "Овощные консервы", "subcategory"...

# %%
reports_dir = Path("table_reports")
reports_dir.mkdir(exist_ok=True)

key_tables = ["user", "product", "orders", "order_item", "event"]

for t in key_tables:
    if t not in tables:
        continue
    print("=" * 60)
    print(f"⭐ Ключевая таблица: {t}")
    print("=" * 60)
    
    df = load_table(conn, t)
    display(df)
    
    if HAS_PROFILING and len(df) > 0:
        profile = ProfileReport(df, title=f"Key table profile: {t}", minimal=True)
        html_path = reports_dir / f"key_{t}_profile.html"
        profile.to_file(html_path)
        print(f"Profile для {t} сохранён в {html_path}\n")
# Out:
# ============================================================
# ⭐ Ключевая таблица: user
# ============================================================
#     id    username                                      password_hash  \
# 0    1        asnp  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 1    2       test2  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 2    3      test22  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 3    4     test123  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 4    5    test1234  03ac674216f3e15c761ee1a5e255f067953623c8b388b4...
# 5    6   test12345  48875c7264f7e22024b8953a1c8884972d97ff724a84e3...
# 6    7  test123456  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 7    8      123451  a665a45920422f9d417e4867efdc4fb8a04a1f3fff1fa0...
# 8    9   123123123  932f3c1b56257ce8539ac269d7aab42550dacf8818d075...
# 9   10         фыв  6ce2b11b62f74576177a63f621be551a946ca1a6f857f4...
# 10  11      123321  a320480f534776bddb5cdb54b1e93d210a3c7d199e80a2...
# 11  12         332  7104741a92e73eb6c5d69cd04cf0afbe50a8796a010d8f...
# 12  13        2121  b8dc2c143be8994682b08461f46487e05874e59dd9ab65...
# 13  14        5454  5ad0e75a5119ff6de36d3fab783202c0224e685aa48461...
# 14  15    12345175  937e8d5fbb48bd4949536cd65b8d35c426b80d2f830c5c...
# 15  16         asd  688787d8ff144c502c7f5cffaafe2cc588d86079f9de88...
# 16  17        swin  0a2fd6bc749fe44d435adbf48abc1afdda50b986c9dc1f...
# 17  18       swin2  b6bd738326ba9ce6854a30cbe3c83b2a1b20ee0b830d8e...
# 18  19       swin3  7328ed12e2feb9c6798738481965b3d870a008051a57b4...
# 19  20       swin4  2c034cb704cae865509299228328c8794ab0dc86c2730d...
# 20  21       swin5  9d4f2584664dca26d4d576d67e44e9c9821fe0d9fd9cfe...
# 21  22           ф  2efb3b9183cd5cbd640874c3de9be1e7261b1382129b32...
# 22  23        sex1  7fb52da155620b9187d31044726383122aff8e777bd885...
# 23  24        sex2  8dd8917251f6944c99fcd4b33d759de5c2bcccffa35126...
# 24  25        sex3  a76a9ce3689eb79d839740fdbc295949385d3925d7885e...
# 25  26        sex4  1d772baf3c6c102fe16d03b871d193c9ca0935c5d561aa...
# 26  27        sex5  cacf2620d3b9cd4099cee4bf082da0894b7b7845e06dc3...
# 27  28        sex6  f0abe964185670f8ffcbca180bf28e258e87cb0703930a...
# 28  29          q1  c75de8c1b7c3ae5252091267a736a9bf57001d80e82668...
# 29  30          q2  bee98bf120e8906382754c6be52860ac5dbc65a1ca4dbe...
# 30  31          q3  58e2791934fdd9cfdd6d0e892cb6ca4894abc58559de0e...
# 31  32          q4  112f2dfa31205df3f5f9db109460c8b85067d7dc27f707...
# 32  33          g1  711430f6164e93803d93428bc1fab80f41e213bb197689...
# 33  34          ц2  3d4289f759756f9d050bbfe1ff9ee7eaec5286a3c89d7c...
# 34  35         555  91a73fd806ab2c005c13b4dc19130a884e909dea3f72d4...
# 35  36        sss1  9e00189f447974400a5372aad636b11d4ebf48ff1588e8...
# 36  37      asdasd  5fd924625f6ab16a19cc9807c7c506ae1813490e4ba675...
# 37  38          t1  628b49d96dcde97a430dd4f597705899e09a968f793491...
# 38  39          ff  05a9bf223fedf80a9d0da5f73f5c191a665bf4a0a4a3e6...
# 39  40          hh  72b289ec78e0a928c565480a435453e30acb92eddb3b78...
# 40  41         ddd  730f75dafd73e047b86acb2dbd74e75dcb93272fa084a9...
# 41  42         вав  83f0c4a8b925cde65a6445859add474aecd871f6d2321c...
# 42  43      zovzov  670e6ce7b5106a3d07e6565db7865fd5d159fc3df50c7e...
# 43  44         SVO  df98806ab8e1859e6dc22cc7980c438162e2ee72d64f0e...
# 44  45      SVOSVO  f7a025973bba26ac81017651d3b04e7a65de9edb8501a6...
#
#              created_at
# 0   2025-11-16 23:01:01
# 1   2025-11-16 23:04:13
# 2   2025-11-17 03:27:33
# 3   2025-11-17 03:30:51
# 4   2025-11-17 03:32:27
# 5   2025-11-17 05:30:51
# 6   2025-11-17 05:31:56
# 7   2025-11-17 07:51:53
# 8   2025-11-17 07:56:13
# 9   2025-11-17 08:43:02
# 10  2025-11-17 08:43:58
# 11  2025-11-17 08:44:13
# 12  2025-11-17 08:44:28
# 13  2025-11-17 08:45:24
# 14  2025-11-17 12:22:51
# 15  2025-11-17 19:25:04
# 16  2025-11-17 19:36:42
# 17  2025-11-17 19:36:58
# 18  2025-11-17 19:39:08
# 19  2025-11-17 19:39:08
# 20  2025-11-17 19:39:09
# 21  2025-11-17 19:43:41
# 22  2025-11-17 19:53:46
# 23  2025-11-17 19:54:03
# 24  2025-11-17 19:54:42
# 25  2025-11-17 19:55:00
# 26  2025-11-17 19:55:11
# 27  2025-11-17 19:55:20
# 28  2025-11-17 20:01:36
# 29  2025-11-17 20:02:15
# 30  2025-11-17 20:02:34
# 31  2025-11-17 20:02:47
# 32  2025-11-17 20:13:12
# 33  2025-11-17 20:13:46
# 34  2025-11-17 20:37:59
# 35  2025-11-17 20:53:44
# 36  2025-11-17 20:55:06
# 37  2025-11-17 20:56:43
# 38  2025-11-17 20:58:40
# 39  2025-11-17 21:00:35
# 40  2025-11-17 21:03:09
# 41  2025-11-17 21:51:47
# 42  2025-11-17 21:57:49
# 43  2025-11-17 21:59:26
# 44  2025-11-17 21:59:54
# ============================================================
# ⭐ Ключевая таблица: product
# ============================================================
#          id                                               name  \
# 0         1                             Абрикос мытый, Фрешбар
# 1         2  Абрикос Планета Витаминов без косточки заморож...
# 2         3                                   Абрикосы сушеные
# 3         5                                             Аджика
# 4         6                    Аджика / Соус Фирменный KERAKUR
# ...     ...                                                ...
# 8704  10458        Зразы "Сахалинские" из горбуши с сыром, зам
# 8705  10459                    Зубатка пестрая стейк мороженая
# 8706  10460                          Зубатка пестрая стейк зам
# 8707  10461                          Зубатка пестрая стейк зам
# 8708  10462                                  Звездочки медовые
#
#                                               image_url  price unit  \
# 0     https://img.vkusvill.ru/pim/images/site/62d3b0...  165.0   шт
# 1     https://img.vkusvill.ru/pim/images/site/a2549a...  199.0   шт
# 2     https://img.vkusvill.ru/pim/images/site/96ffdd...  328.0   шт
# 3     https://img.vkusvill.ru/pim/images/site/site/2...  184.0   шт
# 4     https://img.vkusvill.ru/pim/images/site/259f77...  335.0   шт
# ...                                                 ...    ...  ...
# 8704  https://img.vkusvill.ru/pim/images/site/5478ed...  425.0   шт
# 8705  https://img.vkusvill.ru/pim/images/site/1a96f9...  920.0   кг
# 8706  https://img.vkusvill.ru/pim/images/site/7ebdd6...  910.0   кг
# 8707  https://img.vkusvill.ru/pim/images/site/9b5aa6...  595.0   шт
# 8708  https://img.vkusvill.ru/pim/images/site/775306...   98.0   шт
#
#       weight_value weight_unit  rating shelf_life_days  category_id  \
# 0            300.0           г     0.0            None            0
# 1            250.0           г     4.6            None            1
# 2            200.0           г     4.8            None            2
# 3            200.0           г     4.8            None            3
# 4            480.0           г     4.8            None            1
# ...            ...         ...     ...             ...          ...
# 8704         300.0           г     4.7            None           10
# 8705           NaN                 4.6            None           10
# 8706           NaN                 4.9            None           10
# 8707         600.0           г     4.7            None           10
# 8708         200.0           г     4.9            None           19
#
#                   brand                                        description  \
# 0              ВкусВилл  Медовой спелости абрикосы, тщательно отобранны...
# 1     Планета Витаминов  Линейка Гурманики дополняется новым продуктом ...
# 2              ВкусВилл  Сушеные абрикосы способны быстро утолить голод...
# 3              ВкусВилл  Острая аджика с насыщенным вкусом и густой тек...
# 4               Kerakur  Аджика неострая , подается к мясным и куриным ...
# ...                 ...                                                ...
# 8704           ВкусВилл  Зразы с горбушей и сыром, которые при обжарке ...
# 8705           ВкусВилл  Дикую зубатку вылавливают в Баренцевом море. А...
# 8706           ВкусВилл  Замороженные стейки дикой пёстрой зубатки. Мяс...
# 8707           ВкусВилл  Замороженные стейки дикой пёстрой зубатки. Мяс...
# 8708           ВкусВилл  Аппетитные мультизлаковые звёздочки с натураль...
#
#                                             composition  \
# 0                                        абрикос свежий
# 1                                               Абрикос
# 2                         абрикосы сушеные без косточки
# 3     перец красный сладкий свежий, паста томатная (...
# 4     красный перец, томатная паста, красный острый ...
# ...                                                 ...
# 8704  горбуша,  сыр полутвердый м.д.ж в сухом вещест...
# 8705  Зубатка пестрая, вода питьевая (защитная глазу...
# 8706  зубатка пёстрая, вода питьевая (защитная глазурь)
# 8707  Зубатка пестрая, вода питьевая (защитная глазу...
# 8708  зерновые продукты (крупа кукурузная,  крупа ри...
#
#                                                metadata
# 0     {"category": "Фрукты", "subcategory": "Фруктов...
# 1     {"category": "Замороженные ягоды", "subcategor...
# 2     {"category": "Орехи, чипсы и снеки", "subcateg...
# 3     {"category": "Консервация", "subcategory": "Ху...
# 4     {"category": "Овощные консервы", "subcategory"...
# ...                                                 ...
# 8704  {"category": "Рыба, икра и морепродукты", "sub...
# 8705  {"category": "Рыба, икра и морепродукты", "sub...
# 8706  {"category": "Рыба, икра и морепродукты", "sub...
# 8707  {"category": "Рыба, икра и морепродукты", "sub...
# 8708  {"category": "Крупы, макароны, мука", "subcate...
#
# [8709 rows x 14 columns]
# ============================================================
# ⭐ Ключевая таблица: orders
# ============================================================
#    id  user_id           order_time   status  total_price
# 0   1        1  2025-11-16 23:03:48  created       1591.0
# 1   2        1  2025-11-16 23:04:05  created       4950.0
# 2   3        1  2025-11-16 23:39:57  created        835.0
# 3   4       15  2025-11-17 13:20:27  created       2283.0
# 4   5       15  2025-11-17 13:22:09  created       1549.0
# 5   6       15  2025-11-17 13:46:26  created       3032.0
# 6   7       24  2025-11-17 19:54:37  created       2071.0
# 7   8       29  2025-11-17 20:02:01  created       1814.0
# 8   9       34  2025-11-17 20:15:20  created       2356.0
# ============================================================
# ⭐ Ключевая таблица: order_item
# ============================================================
#     id  order_id  product_id  quantity   price
# 0    1         1        4324         1   115.0
# 1    2         1         446         1   239.0
# 2    3         1        8852         1   420.0
# 3    4         1       10128         1   209.0
# 4    5         1        1528         1   608.0
# 5    6         2           1        30   165.0
# 6    7         3           1         2   165.0
# 7    8         3           3         1   328.0
# 8    9         3         409         1   177.0
# 9   10         4        8780         1  1722.0
# 10  11         4        4815         4   129.0
# 11  12         4        9386         1    45.0
# 12  13         5       10391         1   620.0
# 13  14         5         290         1    50.0
# 14  15         5        6139         1    82.0
# 15  16         5        4948         1   499.0
# 16  17         5        1284         1   298.0
# 17  18         6        6641         1   180.0
# 18  19         6        6644         1   310.0
# 19  20         6        5585         1   335.0
# 20  21         6       10252         1   105.0
# 21  22         6        5233         1   220.0
# 22  23         6        8967         1   103.0
# 23  24         6          27         1   295.0
# 24  25         6        4137         1   150.0
# 25  26         6        8166         1   210.0
# 26  27         6        6305         1   193.0
# 27  28         6        1046         1   235.0
# 28  29         6        4026         1    66.0
# 29  30         6        2088         1   480.0
# 30  31         6        4148         1   150.0
# 31  32         7           2         1   199.0
# 32  33         7           5         1   184.0
# 33  34         7           3         1   328.0
# 34  35         7           1         1   165.0
# 35  36         7           8         1   370.0
# 36  37         7        3982         1   175.0
# 37  38         7        3986         1   180.0
# 38  39         7        4174         1   470.0
# 39  40         8           1         1   165.0
# 40  41         8           2         1   199.0
# 41  42         8        8118         1   525.0
# 42  43         8          25         3   247.0
# 43  44         8           5         1   184.0
# 44  45         9           1         1   165.0
# 45  46         9           3         1   328.0
# 46  47         9           5         2   184.0
# 47  48         9           9         1    85.0
# 48  49         9           8         2   370.0
# 49  50         9           6         1   335.0
# 50  51         9           7         1   335.0
# ============================================================
# ⭐ Ключевая таблица: event
# ============================================================
#         id  user_id                        session_id           event_time  \
# 0        1        1  0ef7b4abecac4382914ce4dcefde59fd  2025-11-16 23:01:33
# 1        2        1  0ef7b4abecac4382914ce4dcefde59fd  2025-11-16 23:01:33
# 2        3        1  0ef7b4abecac4382914ce4dcefde59fd  2025-11-16 23:01:33
# 3        4        1  0ef7b4abecac4382914ce4dcefde59fd  2025-11-16 23:01:33
# 4        5        1  0ef7b4abecac4382914ce4dcefde59fd  2025-11-16 23:01:33
# ...    ...      ...                               ...                  ...
# 2626  2627       45  3d1c9812f9654025afa0c98c550638b8  2025-11-17 22:00:16
# 2627  2628       45  3d1c9812f9654025afa0c98c550638b8  2025-11-17 22:00:16
# 2628  2629       45  3d1c9812f9654025afa0c98c550638b8  2025-11-17 22:00:16
# 2629  2630       45  3d1c9812f9654025afa0c98c550638b8  2025-11-17 22:00:16
# 2630  2631       45  3d1c9812f9654025afa0c98c550638b8  2025-11-17 22:00:16
#
#           event_type  item_id     page_type  source experiment_key  \
# 0        add_to_cart   4324.0        search  search           None
# 1     rec_impression   1528.0  recs_sidebar    recs           None
# 2     rec_impression   4188.0  recs_sidebar    recs           None
# 3     rec_impression   4577.0  recs_sidebar    recs           None
# 4     rec_impression   4589.0  recs_sidebar    recs           None
# ...              ...      ...           ...     ...            ...
# 2626  rec_impression   6315.0  recs_sidebar    recs   main_recs_ab
# 2627  rec_impression   6332.0  recs_sidebar    recs   main_recs_ab
# 2628  rec_impression   8452.0  recs_sidebar    recs   main_recs_ab
# 2629  rec_impression   8689.0  recs_sidebar    recs   main_recs_ab
# 2630  rec_impression  10380.0  recs_sidebar    recs   main_recs_ab
#
#            variant  position value                        request_id  \
# 0             None       1.0  None  fdb61fbebd95459aa87aceb4df5e0a1f
# 1             None       1.0  None  2d5bfea386484bb58cfc5599e7985d68
# 2             None       2.0  None  2d5bfea386484bb58cfc5599e7985d68
# 3             None       3.0  None  2d5bfea386484bb58cfc5599e7985d68
# 4             None       4.0  None  2d5bfea386484bb58cfc5599e7985d68
# ...            ...       ...   ...                               ...
# 2626  ease_popular       4.0  None  1941662608fd4fa28819dd9936ccc6ca
# 2627  ease_popular       5.0  None  1941662608fd4fa28819dd9936ccc6ca
# 2628  ease_popular       6.0  None  1941662608fd4fa28819dd9936ccc6ca
# 2629  ease_popular       7.0  None  1941662608fd4fa28819dd9936ccc6ca
# 2630  ease_popular       8.0  None  1941662608fd4fa28819dd9936ccc6ca
#
#                                                metadata
# 0            {"query": "спагетти", "cart": {"4324": 1}}
# 1                                 {"cart": {"4324": 1}}
# 2                                 {"cart": {"4324": 1}}
# 3                                 {"cart": {"4324": 1}}
# 4                                 {"cart": {"4324": 1}}
# ...                                                 ...
# 2626  {"cart": {"2": 1, "3": 2, "5": 2, "1040": 1, "...
# 2627  {"cart": {"2": 1, "3": 2, "5": 2, "1040": 1, "...
# 2628  {"cart": {"2": 1, "3": 2, "5": 2, "1040": 1, "...
# 2629  {"cart": {"2": 1, "3": 2, "5": 2, "1040": 1, "...
# 2630  {"cart": {"2": 1, "3": 2, "5": 2, "1040": 1, "...
#
# [2631 rows x 14 columns]

# %%
def max_matching(adj: dict[int, list[int]]) -> dict[int, int]:

    matchR = {}

    def dfs(u, seen):
        for v in adj[u]:
            if v in seen:
                continue
            seen.add(v)

            if v not in matchR or dfs(matchR[v], seen):
                matchR[v] = u
                return True
        return False

    for u in adj:
        dfs(u, set())

    matchL = {u: v for v, u in matchR.items()}
    return matchL

# %%
adj = {
    1:  [2, 5, 7],
    2:  [1, 3],
    3:  [4, 8, 9, 12],
    4:  [5],
    5:  [1, 6, 7, 8],
    6:  [3, 9],
    7:  [2, 4, 6],
    8:  [10, 11],
    9:  [5, 7, 12],
    10: [8]
}



matching = max_matching(adj)
print(len(matching))
print(matching)
# Out:
# 10
# {7: 2, 2: 1, 3: 4, 4: 5, 6: 3, 5: 6, 1: 7, 8: 10, 10: 8, 9: 12}
